# %%
import DPQ
import numpy as np
import QuantumTomography as qKLib

# %% [raw]
# Teste nova hamiltoniana:

# %%
dpq = DPQ.DinamicaPontosQuanticos()

# %%
#definindo os parametros para a hamiltoniana
mhz = 10**(-3)
pi = np.pi
j_1 = 280*mhz*2*pi
j_2 = 320*mhz*2*pi
bz_1 = (pi/16)*(10**3)*mhz
bz_2 = (pi/16)*(10**3)*mhz
j12 = pi/140
h = dpq.hamiltoniana_Nova(j_1, j_2, bz_1, bz_2, j12)
#Esse É O CENTRAL, variar o bz1 e o bz2 com 20%
#Mantendo o j1 e j2 fixos

# %%
h
# Out:
# array([[ 1.87934561,  0.09817477,  0.09817477,  0.        ],
#        [ 0.09817477, -0.13127369,  0.        ,  0.09817477],
#        [ 0.09817477,  0.        ,  0.12005372,  0.09817477],
#        [ 0.        ,  0.09817477,  0.09817477, -1.86812563]])

# %%
ro = dpq.ro(h, 800)
#dpq.concurrence(ro)

print("Minha Concurrence:", dpq.concurrence(ro))
print("Concurrence:", qKLib.concurrence(ro))
print("Entropy:", qKLib.entropy(ro))
# Out:
# Minha Concurrence: (0.5146750977271248-2.4747826152552086e-09j)
# Concurrence: 0.5146751014660013
# Entropy: 3.9822135531747466e-14

# %%
tempos = np.arange(1500, step=1)

# %%
concurrence = []
for tempo in tempos:
    ro = dpq.ro(h, tempo)
    concurrence.append(dpq.concurrence(ro))

# %%
import matplotlib.pyplot as plt

x = concurrence
y = tempos

fig, ax = plt.subplots(figsize=(20,10))

# Using set_dashes() to modify dashing of an existing line
line1, = ax.plot(y,x , label=' ')

ax.legend()
plt.show()

# %% [raw]
# Conteúdo:
# 1)Intervalos - | a = \[1;1\] ;b = \[1;1\];j= \[0;10\] ; T= \[5;25\] PJ= 0.1 |
# 2)Intervalos - | a =\[1;1\] ;b = \[1;1\];j= \[0;10\]; T= \[5;25\] PJ= 0.01 |
# 2)Intervalos - | a =\[1;1\] ;b = \[1;1\];j= \[0;10\]; T= \[5;25\] PJ= 0.001 |
# 4)Intervalos - | a =\[0;1\] ;b = \[0;1\];j= \[0;10\]; T= \[5;25\] PJ= 0.01 |
# 5)Intervalos - | a =\[0;1\] ;b = \[0;1\];j= \[0;10\] ; T= \[5;25\] PJ= 0.01 |

# %%
dpq = DPQ.DinamicaPontosQuanticos(aInicial = 1, aFinal =1, bInicial = 1, bFinal = 1, jInicial = 0, jFinal = 10 , passoJ = 0.1)
dpq.saveDataFrame()
# Out:
# colunas: 33
# Total tempo gasto:  0.25941880099708214
# results shape: (3333,)
# Tamanho: 3333
# linhas: 101

# %%
from qutip import *
teste = Qobj(ro_300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-48bf737ba499> in <module>
#       1 from qutip import *
# ----> 2 teste = Qobj(ro_300)
#
# NameError: name 'ro_300' is not defined

# %%
import QuantumTomography as qKLib
qKLib.concurrence(ro_300)

# %%
help(qKLib.TomoFunctions)

# %%
concurrence(Qobj(dpq.hamiltoniana(1,1,1)))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-25-eb4af8e7e17f> in <module>
# ----> 1 concurrence(Qobj(dpq.hamiltoniana(1,1,1)))
#
# ~/anaconda3/envs/numpyTest/lib/python3.8/site-packages/qutip/entropy.py in concurrence(rho)
#     136
#     137     elif rho.isoper and rho.dims != [[2, 2], [2, 2]]:
# --> 138         raise Exception("Density matrix must be tensor product of two qubits.")
#     139
#     140     if rho.isket or rho.isbra:
#
# Exception: Density matrix must be tensor product of two qubits.

# %%
concurrence(teste)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-fee82a816e64> in <module>
# ----> 1 concurrence(teste)
#
# ~/anaconda3/envs/numpyTest/lib/python3.8/site-packages/qutip/entropy.py in concurrence(rho)
#     136
#     137     elif rho.isoper and rho.dims != [[2, 2], [2, 2]]:
# --> 138         raise Exception("Density matrix must be tensor product of two qubits.")
#     139
#     140     if rho.isket or rho.isbra:
#
# Exception: Density matrix must be tensor product of two qubits.

# %%
ro(t, h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0c86322a3ea8> in <module>
# ----> 1 ro(t, h)
#
# NameError: name 'ro' is not defined

# %%
from qutip import *

# %%
#Criando as matrizes de Pauli-X, Pauli-Y, e Pauli-Z.
sigmaX = np.array([[0, 1], [1, 0]])
sigmaY = np.array([[0, -1j], [1j, 0]])
sigmaZ = np.array([[1, 0], [0, -1]])

#Matriz identidade.
ident = np.identity(2)

# %%
t = DensityMatrix(ro, d
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-63-a9c0b21d30cb> in <module>
# ----> 1 t = DensityMatrix(ro, dims=(1,1))
#
# ~/anaconda3/envs/numpyTest/lib/python3.8/site-packages/qiskit/quantum_info/states/densitymatrix.py in __init__(self, data, dims)
#     105             raise QiskitError(
#     106                 "Invalid DensityMatrix input: not a square matrix.")
# --> 107         super().__init__(op_shape=OpShape.auto(
#     108             shape=self._data.shape, dims_l=dims, dims_r=dims))
#     109
#
# ~/anaconda3/envs/numpyTest/lib/python3.8/site-packages/qiskit/quantum_info/operators/op_shape.py in auto(cls, shape, dims_l, dims_r, dims, num_qubits_l, num_qubits_r, num_qubits)
#     269         # Validate shape
#     270         if shape:
# --> 271             matrix_shape.validate_shape(shape)
#     272         return matrix_shape
#     273
#
# ...

# %%
concurrence(t)
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-61-4a1dbf4dd929> in <module>
# ----> 1 concurrence(t)
#
# ~/anaconda3/envs/numpyTest/lib/python3.8/site-packages/qiskit/quantum_info/states/measures.py in concurrence(state)
#     194     """
#     195     # Concurrence computation requires the state to be valid
# --> 196     state = _format_state(state, validate=True)
#     197     if isinstance(state, Statevector):
#     198         # Pure state concurrence
#
# ~/anaconda3/envs/numpyTest/lib/python3.8/site-packages/qiskit/quantum_info/states/utils.py in _format_state(state, validate)
#     132         raise QiskitError("Input is not a quantum state")
#     133     if validate and not state.is_valid():
# --> 134         raise QiskitError("Input quantum state is not a valid")
#     135     return state
#     136
#
# QiskitError: 'Input quantum state is not a valid'

# %%
t.evaluate(t,t=1000,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-f9c7e897b1ac> in <module>
# ----> 1 t.evaluate(t,t=1000,)
#
# TypeError: evaluate() missing 1 required positional argument: 'args'
