# %% [markdown]
# # 1-Simulação hamiltoniana

# %% [markdown]
# #### A Equação que queremos simular é:
# ![Screenshot from 2022-02-09 03-22-19.png](attachment:ccaf8918-2b79-48f1-b9f8-dcc10660b264.png)

# %% [markdown]
# #### Dividimos em 5 partes chamadas de Hn, sendo n=5. Os termos são:
#
# #### H1*(1/2):
# ![Screenshot from 2022-02-09 03-26-29.png](attachment:18b15871-e534-4a17-8102-9acc2b932ab5.png)
#
# #### H2*(1/2):
# ![Screenshot from 2022-02-09 03-28-14.png](attachment:f4b7b96d-e189-4ba9-ba51-f5ce669da59e.png)
#
# #### H3:
# ![Screenshot from 2022-02-09 03-29-04.png](attachment:70613cbf-74d4-4277-8cd4-4170e3396f32.png)
#
# #### H4*(1/2):
# ![Screenshot from 2022-02-09 03-29-49.png](attachment:6f11548b-60af-47d8-949a-818baa9d2251.png)
#
# #### H5*(1/2):
# ![Screenshot from 2022-02-09 03-30-36.png](attachment:61d26165-8662-4cdf-8bec-6a1179b5ceab.png)

# %% [markdown]
# ## 2- Fase: Teste das porções individuais com parametros setados como 1.

# %% [markdown]
# #### Nesta fase separamos os circuitos das hamiltonianas e fizemos a comparação com os resultados clássicos. Ainda nesta faze foi utilizado uma simulação de computador quantico para efetuar os testes e nenhum modelo de erro foi utilizado. Foi efetuado a comparação sem trotter-suzuki, com trotter-suzuki primeira ordem e segunda ordem.

# %% [markdown]
# ## Simulação H1

# %% [markdown]
# #### A simulaçao do H1 foi feita com sucesso para t=1, a implementação de trotter de segunda ordem bateu a de primeira com n=10, a de primeira ordem precisou de 1000 pedaços de tempo para chegar no mesmo resultado.
#
#
# Nota:Preciso confirmar se foi realmente isso que aconteceu devido aos resultados que eu obtive em H2, ainda estava chegando em um circuito e posso ter feito correções após implementação de trotter-suzuki)

# %% [markdown]
# ### O cicuito para h1 é:
# ![Screenshot from 2022-02-10 04-07-18.png](attachment:31ef1d7d-f863-48f7-9068-ba4fb8beb2ab.png)

# %% [markdown]
# ### Matrix densidade
# ### Quantica identica a classica:
#
# ![Screenshot from 2022-02-10 03-46-50.png](attachment:79846796-7fc3-4c07-82af-c3dda86e6661.png)
# ![Screenshot from 2022-02-10 03-47-54.png](attachment:b0cbafcb-8c58-4522-adf6-d4921a84ebcf.png)

# %% [markdown]
# ## Simulação H2

# %% [markdown]
# #### O circuito para H2 ficou:
#   ![Screenshot from 2022-02-09 03-58-09.png](attachment:5317722b-924d-4e5e-9fd6-487a721a1a0a.png)

# %% [markdown]
# #### Matrix densidade quantica (Sem trotter-suzuki):
# ![Screenshot from 2022-02-09 04-00-30.png](attachment:57435eff-f957-4d31-b105-d6bdd83b1de5.png)
#
# #### Matrix densidade classica:
# ![Screenshot from 2022-02-09 04-00-44.png](attachment:d73a648d-a765-49d4-b0d2-8d93d638512b.png)

# %% [markdown]
# #### O circuito para H2 com trotter suzuki primeira ordem, é:
# ![Screenshot from 2022-02-09 05-06-00.png](attachment:4c57d867-a463-4186-bcd1-be2b9f840eac.png)

# %% [markdown]
# ##### OBS: é apenas uma parte do circuito quando j2=1 e n = 100(n nesse contexto é o numero de divisões, no algoritmo representado pela letra r! atenção professor.)

# %% [markdown]
# #### O circuito da imagem é apenas uma pequena parcela do total. O circuito trata-se apenas de uma repetição de n-vezes do circuito de H2 unico.

# %% [markdown]
# #### Resultados: Matrix densidade quântica identica para os 3 testes, sem trotter-suzuki, com totter-suzuki primeira ordem e segunda, independente do valor de n colocado.

# %% [markdown]
# ## Simulação H3

# %% [markdown]
# ### Comecei tentando simular a expressão inteira, mas acho que não dá para simular dessa forma. Acho que quando passamos a formula de trotter suzuki houve um mal entendido da minha parte, e eu dividi de acordo com os termos que multiplicam os parametros. Tentei simular o circuito completo e não consegui. Porisso subdividi o H3 em mais 3 partes.

# %% [markdown]
# ### Sem mais delongas, segue a equação h3 parte 1:
# ![Screenshot from 2022-02-10 02-40-50.png](attachment:ba1e86f4-fdfe-4da7-b03a-7d91089c9e6e.png)

# %% [markdown]
# ### Lembrando que tem um termo de 1/4 multiplicando o J12 que faz parte do parametro deste termo. Então, como os outros circuitos eram multiplicados por 1/2 e não precisamos multiplicar o resultado por causa da maneira como o gate é implementada, neste circuito vamos multiplicar a entrada por 1/2 por ele corresponder a parte de 1/4.

# %% [markdown]
# #### O circuito para H3-1 ficou:
# ![Screenshot from 2022-02-10 03-06-22.png](attachment:580b2759-8ad3-41bc-9691-835c5193b0c9.png)

# %% [markdown]
# #### Matrix densidade quantica (Sem trotter-suzuki):
# ![Screenshot from 2022-02-10 03-07-03.png](attachment:bcfb842c-f95f-4a2b-8452-42d2a5e5fa78.png)
# #### Matrix densidade classica:
# ![Screenshot from 2022-02-10 03-09-00.png](attachment:23bc204a-cda2-4578-9b43-bd14b573065d.png)

# %% [markdown]
# #### O circuito h3-2 e h3-2, são identicos ao circuito h1. apenas seu parametro é dividido por -1/2. O circuito foi testado e todas as matrizes corresponderam ao desejado.

# %% [markdown]
# ## Simulação H4

# %% [markdown]
# #### O circuito para H4 ficou:
# ![Screenshot from 2022-02-10 04-47-54.png](attachment:623018ab-30fa-4914-bfa0-286dadbc407f.png)

# %% [markdown]
# ![Screenshot from 2022-02-10 04-49-09.png](attachment:016b22d2-41da-4e74-9523-16148de38b7d.png)
# ![Screenshot from 2022-02-10 04-49-09.png](attachment:e24afd31-7a51-45ce-8163-e9e225229bc3.png)

# %% [markdown]
# ## Simulação H5

# %% [markdown]
# #### O circuito para h5 ficou:
# ![Screenshot from 2022-02-10 06-18-37.png](attachment:7a40531f-36b2-4fbb-b6b5-09fcb17f4b60.png)

# %% [markdown]
# ![Screenshot from 2022-02-10 04-49-09.png](attachment:016b22d2-41da-4e74-9523-16148de38b7d.png)
# ![Screenshot from 2022-02-10 04-49-09.png](attachment:e24afd31-7a51-45ce-8163-e9e225229bc3.png)

# %% [markdown]
# ## 3- Fase: Teste de todos os circuitos juntos com parametros setados como 1.

# %% [markdown]
# #### Nesta fase meu objetivo é juntar todos os circuitos testados na fase anterior, o que representa a hamiltoniana completa.

# %% [markdown]
# #### O circuito:
# ![Screenshot from 2022-02-10 08-43-06.png](attachment:1dba2f40-40c2-4845-956d-401c28b5915f.png)

# %% [markdown]
# #### O resultado para trotter deprimeira ordem não deu certo com o n que eu consigo testar aqui de forma prática. O resultado da trotter-suzuki de segunda ordem com n=100000 é o abaixo:
# ![Screenshot from 2022-02-10 08-37-35.png](attachment:31bb5836-f293-4a2d-af63-17464edbd31d.png)

# %% [markdown]
# ## Correção:

# %% [markdown]
# ## Simulação H1

# %% [markdown]
# #### A simulaçao do H1 foi feita com sucesso para t=1, a implementação de trotter de segunda ordem bateu a de primeira com n=10, a de primeira ordem precisou de 1000 pedaços de tempo para chegar no mesmo resultado.
#
#
# Nota:Preciso confirmar se foi realmente isso que aconteceu devido aos resultados que eu obtive em H2, ainda estava chegando em um circuito e posso ter feito correções após implementação de trotter-suzuki)

# %% [markdown]
# ### O cicuito para h1 é:
# ![Screenshot from 2022-02-10 04-07-18.png](attachment:31ef1d7d-f863-48f7-9068-ba4fb8beb2ab.png)
